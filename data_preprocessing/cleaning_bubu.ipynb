# %%
import pandas as pd
import csv

# Read the appended CSV file into a DataFrame
df = pd.read_csv('../raw_data/appended_flight_data.csv')

# %%
import missingno as msno
msno.bar(df)
    # we want to delete the datapoints with more the 80% (<600) missing points. 
    # here we will look into each of these columns to see if there is any reason to keep them.
# Out:
# <Axes: >

# %%
# Examine TRAVEL_SERVICES_amenityProvider

# Looking at unique values
unique_values = df['TRAVEL_SERVICES_amenityProvider'].unique()

# Print the unique values
print("Unique values:", unique_values)

# Missing values
missing_values = df['TRAVEL_SERVICES_amenityProvider'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Number of missing values: 649 - this is way too many and all of the unique values are the same 'BrandedFare'.
    # we can thus delete this column.
# Out:
# Unique values: [nan 'BrandedFare; BrandedFare' 'BrandedFare'
#  'BrandedFare; BrandedFare; BrandedFare']
# Number of missing values: 649

# %%
# Examine TRAVEL_SERVICES_isChargeable

# Looking at unique values
value_counts = df['TRAVEL_SERVICES_isChargeable'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['TRAVEL_SERVICES_isChargeable'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Number of missing values: 649 -> not a lot of variation in values so they do not add anything to our objective. 
    # we should also delete this column.
# Out:
# Frequency of each value:
# TRAVEL_SERVICES_isChargeable
# True; True          58
# True; True; True    14
# True                13
# False; False         1
# Name: count, dtype: int64
# Number of missing values: 649

# %%
# Examine TRAVEL_SERVICES_description

# Looking at unique values
value_counts = df['TRAVEL_SERVICES_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['TRAVEL_SERVICES_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Number of missing values: 649 -> It could be interesting to look at if the plane has wifi and if that drives price. 
# however, out of 735 points, 649 are missing and only 13 occurences of wifi. the data is very unbalanced, so we will
# not look at this and delete it.
# Out:
# Frequency of each value:
# TRAVEL_SERVICES_description
# PRIORITY BOARDING; PRIORITY BOARDING                       59
# PRIORITY BOARDING; PRIORITY BOARDING; PRIORITY BOARDING    14
# WIFI                                                       13
# Name: count, dtype: int64
# Number of missing values: 649

# %%
# Examine PRE_RESERVED_SEAT_amenityProvider

# Looking at unique values
value_counts = df['PRE_RESERVED_SEAT_amenityProvider'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['PRE_RESERVED_SEAT_amenityProvider'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Number of missing values: 576 -> all columns are called "BrandedFare" so we remove this column
# Out:
# Frequency of each value:
# PRE_RESERVED_SEAT_amenityProvider
# BrandedFare; BrandedFare                              106
# BrandedFare; BrandedFare; BrandedFare                  21
# BrandedFare                                            19
# BrandedFare; BrandedFare; BrandedFare; BrandedFare     13
# Name: count, dtype: int64
# Number of missing values: 576

# %%
# Examine PRE_RESERVED_SEAT_isChargeable

# Looking at unique values
value_counts = df['PRE_RESERVED_SEAT_isChargeable'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['PRE_RESERVED_SEAT_isChargeable'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Number of missing values: 576 -> all columns are true or false, but only 1 occurrence of false. We choose to remove this.
# Out:
# Frequency of each value:
# PRE_RESERVED_SEAT_isChargeable
# True; True                105
# True; True; True           21
# True                       19
# True; True; True; True     13
# False; False                1
# Name: count, dtype: int64
# Number of missing values: 576

# %%
# Examine PRE_RESERVED_SEAT_description

# Looking at unique values
value_counts = df['PRE_RESERVED_SEAT_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['PRE_RESERVED_SEAT_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# too many missing values -> 576, there are more oprtions about seating, but too many missing to be useful
# Out:
# Frequency of each value:
# PRE_RESERVED_SEAT_description
# PRE RESERVED SEAT ASSIGNMENT; PRE RESERVED SEAT ASSIGNMENT                                        95
# PRE RESERVED SEAT ASSIGNMENT; PRE RESERVED SEAT ASSIGNMENT; PRE RESERVED SEAT ASSIGNMENT          14
# EXTRA LEG ROOM OR FRONT SEAT; SEAT RESERVATION; EXTRA LEG ROOM OR FRONT SEAT; SEAT RESERVATION    13
# PRE RESERVED SEAT ASSIGNMENT                                                                      13
# EXTRA LEGROOM SEAT RESERVATION; EXTRA LEGROOM SEAT RESERVATION                                    11
# ADVANCE SEAT RESERVATION; ADVANCE SEAT RESERVATION; ADVANCE SEAT RESERVATION                       7
# ADVANCED SEAT SELECTION                                                                            6
# Name: count, dtype: int64
# Number of missing values: 576

# %%
# Examine BRANDED_FARES_amenityProvider

# Looking at unique values
value_counts = df['BRANDED_FARES_amenityProvider'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['BRANDED_FARES_amenityProvider'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# too many missing values -> 217, all values are the same. delete this column
# Out:
# Frequency of each value:
# BRANDED_FARES_amenityProvider
# BrandedFare; BrandedFare; BrandedFare; BrandedFare                                                                                  139
# BrandedFare; BrandedFare                                                                                                            127
# BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare                              121
# BrandedFare; BrandedFare; BrandedFare                                                                                                42
# BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare     40
# BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare                                                         30
# ...

# %%
# Examine BRANDED_FARES_isChargeable

# Looking at unique values
value_counts = df['BRANDED_FARES_isChargeable'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['BRANDED_FARES_isChargeable'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# too many missing values -> 217, true or false if it si chargeable but >80% missing.
# Out:
# Frequency of each value:
# BRANDED_FARES_isChargeable
# True; True; True; True                                          139
# True; False; True; True; True; False; True; True                120
# False; False                                                     69
# True; True                                                       58
# True; True; True                                                 42
# True; False; True; True; True; True; False; True; True; True     40
# False                                                            19
# True; True; True; True; True; True                               16
# True; False; True; False; True; False                             7
# True; False; True; True; False; True                              7
# False; False; False; False; False; False; False; False            1
# Name: count, dtype: int64
# Number of missing values: 217

# %%
# Examine BRANDED_FARES_description

# Looking at unique values
value_counts = df['BRANDED_FARES_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['BRANDED_FARES_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# >80% missing, so we delete this column.
# Out:
# Frequency of each value:
# BRANDED_FARES_description
# CHOICE OF STANDARD SEAT; UPGRADE ELIGIBILITY; CHOICE OF STANDARD SEAT; UPGRADE ELIGIBILITY                                                                                                                                                    139
# STANDARD SEAT RESERVATION; MILEAGE ACCRUAL; UPGRADE ELIGIBILITY; PREFERRED SEAT RESERVATION; STANDARD SEAT RESERVATION; MILEAGE ACCRUAL; UPGRADE ELIGIBILITY; PREFERRED SEAT RESERVATION                                                      120
# MILEAGE ACCRUAL; MILEAGE ACCRUAL                                                                                                                                                                                                               69
# ...

# %%
# Examine ENTERTAINMENT_amenityProvider

# Looking at unique values
value_counts = df['ENTERTAINMENT_amenityProvider'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['ENTERTAINMENT_amenityProvider'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# >80% missing 669 values, so we delete this column. All values are the same as well.
# Out:
# Frequency of each value:
# ENTERTAINMENT_amenityProvider
# BrandedFare; BrandedFare    60
# BrandedFare                  6
# Name: count, dtype: int64
# Number of missing values: 669

# %%
# Examine ENTERTAINMENT_isChargeable

# Looking at unique values
value_counts = df['ENTERTAINMENT_isChargeable'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['ENTERTAINMENT_isChargeable'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# >80% missing 669 values, so we delete this column.
# Out:
# Frequency of each value:
# ENTERTAINMENT_isChargeable
# False; False    60
# True             6
# Name: count, dtype: int64
# Number of missing values: 669

# %%
# Examine ENTERTAINMENT_description

# Looking at unique values
value_counts = df['ENTERTAINMENT_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['ENTERTAINMENT_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# 669 missing -> delete column. Could be interesting with USB power, wisis and online messaging availability on price. 
# but too many missing (most likely only 1 airline has this.)
# Out:
# Frequency of each value:
# ENTERTAINMENT_description
# USB POWER; USB POWER                          46
# ONLINE MESSAGE RIGHT; ONLINE MESSAGE RIGHT    14
# WIFI                                           6
# Name: count, dtype: int64
# Number of missing values: 669

# %%
# Examine MEAL_amenityProvider

# Looking at unique values
value_counts = df['MEAL_amenityProvider'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['MEAL_amenityProvider'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# only missing 83 values -> but all the values are the same, so we discard this column.
# Out:
# Frequency of each value:
# MEAL_amenityProvider
# BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare; BrandedFare    221
# BrandedFare; BrandedFare; BrandedFare; BrandedFare                              197
# BrandedFare; BrandedFare                                                        178
# BrandedFare; BrandedFare; BrandedFare                                            37
# BrandedFare                                                                      19
# Name: count, dtype: int64
# Number of missing values: 83

# %%
# Examine MEAL_isChargeable

# Looking at unique values
value_counts = df['MEAL_isChargeable'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['MEAL_isChargeable'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# Delete if it is chargeable there is barely any variation.

# Examine MEAL_description

# Looking at unique values
value_counts = df['MEAL_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['MEAL_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)

# There are not a lot of missing values, we think this is important to keep. Let's separate the columns.
# Out:
# Frequency of each value:
# MEAL_isChargeable
# False; False                                178
# True; False; True; False                    167
# False; False; False; False; False; False    139
# True; False; True; True; False; True         46
# False; False; False                          37
# False; False; True; False; False; True       36
# False; True; False; True                     30
# False                                        19
# Name: count, dtype: int64
# Number of missing values: 83
# Frequency of each value:
# MEAL_description
# CATERING ON EUROPE FLTS; CATERING ON INTERCONT FLTS; CATERING ON EUROPE FLTS; CATERING ON INTERCONT FLTS                  156
# MEAL AND BEVERAGE; MEAL AND BEVERAGE                                                                                      139
# SNACK; BEVERAGE; MEAL; SNACK; BEVERAGE; MEAL                                                                              139
# ...

# %%
# Examine BAGGAGE_description

# Looking at unique values
value_counts = df['BAGGAGE_description'].value_counts()

# Print the frequency of each value
print("Frequency of each value:")
print(value_counts)

# Missing values
missing_values = df['BAGGAGE_description'].isna().sum()

# Print the number of missing values
print("Number of missing values:", missing_values)
# Out:
# Frequency of each value:
# BAGGAGE_description
# CHECKED BAGGAGE UP TO 23KGS; CHECKED BAGGAGE UP TO 23KGS                                                                                                               139
# CHECKED BAG 1PC OF 23KG 158CM; CHECKED BAG 1PC OF 23KG 158CM                                                                                                           139
# 1ST BAG UPTO50LB23KG 62LI158CM; 1ST BAG UPTO50LB23KG 62LI158CM                                                                                                         118
# CHECKED BAG FIRST; SECOND BAG; CHECKED BAG FIRST; SECOND BAG                                                                                                            58
# CHECKED BAG UP TO 23KG; CHECKED BAG UP TO 23KG                                                                                                                          46
# ...
